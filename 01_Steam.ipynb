# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dti
columns = ['AppID', 'Name', 'Release_date', 'Estimated_owners', 'Peak_CCU',
       'Required_age', 'Price', 'DLC_count', 'About_the_game',
       'Supported_languages', 'Full_audio_languages',
       'Header_image', 'Windows',
       'Mac', 'Linux', 'User_score',
       'Positive', 'Negative', 'Achievements', 'Recommendations', 'Average_playtime_forever', 'Average_playtime_two_weeks',
       'Median_playtime_forever', 'Median_playtime_two_weeks', 'Categories', 'Genres']

df = pd.read_csv('datasets/games1.csv',usecols = columns)
df.columns
#df.head()
# Out:
# Index(['AppID', 'Name', 'Release_date', 'Estimated_owners', 'Peak_CCU',
#        'Required_age', 'Price', 'DLC_count', 'About_the_game',
#        'Supported_languages', 'Full_audio_languages', 'Header_image',
#        'Windows', 'Mac', 'Linux', 'User_score', 'Positive', 'Negative',
#        'Achievements', 'Recommendations', 'Average_playtime_forever',
#        'Average_playtime_two_weeks', 'Median_playtime_forever',
#        'Median_playtime_two_weeks', 'Categories', 'Genres'],
#       dtype='object')

# %%
df.head()
# Out:
#      AppID                   Name Release_date Estimated_owners  Peak_CCU  \
# 0    20200       Galactic Bowling   2008-10-21        0 - 20000         0
# 1   655370           Train Bandit   2017-10-12        0 - 20000         0
# 2  1732930           Jolt Project   2021-11-17        0 - 20000         0
# 3  1355720               Henosis™   2020-07-23        0 - 20000         0
# 4  1139950  Two Weeks in Painland   2020-02-03        0 - 20000         0
#
#    Required_age  Price  DLC_count  \
# 0             0  19.99          0
# 1             0   0.99          0
# 2             0   4.99          0
# 3             0   5.99          0
# 4             0   0.00          0
#
#                                       About_the_game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
# 3  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# ...

# %%
row_count = df['AppID'].count()

print(f'The DataFrame has {row_count} rows.')
# Out:
# The DataFrame has 85103 rows.

# %%
df.dtypes
# Out:
# AppID                           int64
# Name                           object
# Release_date                   object
# Estimated_owners               object
# Peak_CCU                        int64
# Required_age                    int64
# Price                         float64
# DLC_count                       int64
# About_the_game                 object
# Supported_languages            object
# Full_audio_languages           object
# Header_image                   object
# Windows                          bool
# Mac                              bool
# Linux                            bool
# User_score                      int64
# Positive                        int64
# Negative                        int64
# Achievements                    int64
# Recommendations                 int64
# Average_playtime_forever        int64
# Average_playtime_two_weeks      int64
# Median_playtime_forever         int64
# Median_playtime_two_weeks       int64
# Categories                     object
# ...

# %%
casting_dict = {
    'Release_date': 'datetime64[ns]'
}


df['Release_date'] = pd.to_datetime(df['Release_date'], errors='coerce')


df_temp = df.astype(casting_dict)
df_temp.head()
# Out:
#      AppID                   Name Release_date Estimated_owners  Peak_CCU  \
# 0    20200       Galactic Bowling   2008-10-21        0 - 20000         0
# 1   655370           Train Bandit   2017-10-12        0 - 20000         0
# 2  1732930           Jolt Project   2021-11-17        0 - 20000         0
# 3  1355720               Henosis™   2020-07-23        0 - 20000         0
# 4  1139950  Two Weeks in Painland   2020-02-03        0 - 20000         0
#
#    Required_age  Price  DLC_count  \
# 0             0  19.99          0
# 1             0   0.99          0
# 2             0   4.99          0
# 3             0   5.99          0
# 4             0   0.00          0
#
#                                       About_the_game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
# 3  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# ...

# %%
df.dtypes
# Out:
# AppID                                  int64
# Name                                  object
# Release_date                  datetime64[ns]
# Estimated_owners                      object
# Peak_CCU                               int64
# Required_age                           int64
# Price                                float64
# DLC_count                              int64
# About_the_game                        object
# Supported_languages                   object
# Full_audio_languages                  object
# Header_image                          object
# Windows                                 bool
# Mac                                     bool
# Linux                                   bool
# User_score                             int64
# Positive                               int64
# Negative                               int64
# Achievements                           int64
# Recommendations                        int64
# Average_playtime_forever               int64
# ...

# %%
df.isnull()
# Out:
#        AppID   Name  Release_date  Estimated_owners  Peak_CCU  Required_age  \
# 0      False  False         False             False     False         False
# 1      False  False         False             False     False         False
# 2      False  False         False             False     False         False
# 3      False  False         False             False     False         False
# 4      False  False         False             False     False         False
# ...      ...    ...           ...               ...       ...           ...
# 85098  False  False         False             False     False         False
# 85099  False  False         False             False     False         False
# 85100  False  False         False             False     False         False
# 85101  False  False         False             False     False         False
# 85102  False  False         False             False     False         False
#
# ...

# %%
df.isnull().sum()
# Out:
# AppID                            0
# Name                             6
# Release_date                   130
# Estimated_owners                 0
# Peak_CCU                         0
# Required_age                     0
# Price                            0
# DLC_count                        0
# About_the_game                3567
# Supported_languages              0
# Full_audio_languages             0
# Header_image                     0
# Windows                          0
# Mac                              0
# Linux                            0
# User_score                       0
# Positive                         0
# Negative                         0
# Achievements                     0
# Recommendations                  0
# Average_playtime_forever         0
# Average_playtime_two_weeks       0
# Median_playtime_forever          0
# Median_playtime_two_weeks        0
# Categories                    4598
# Genres                        3555
# dtype: int64

# %%
df.dropna(how='all')
df.head()
# Out:
#      AppID                   Name Release_date Estimated_owners  Peak_CCU  \
# 0    20200       Galactic Bowling   2008-10-21        0 - 20000         0
# 1   655370           Train Bandit   2017-10-12        0 - 20000         0
# 2  1732930           Jolt Project   2021-11-17        0 - 20000         0
# 3  1355720               Henosis™   2020-07-23        0 - 20000         0
# 4  1139950  Two Weeks in Painland   2020-02-03        0 - 20000         0
#
#    Required_age  Price  DLC_count  \
# 0             0  19.99          0
# 1             0   0.99          0
# 2             0   4.99          0
# 3             0   5.99          0
# 4             0   0.00          0
#
#                                       About_the_game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
# 3  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# ...

# %%
row_count = df['AppID'].count()

print(f'The DataFrame has {row_count} rows.')
# Out:
# The DataFrame has 85103 rows.

# %% [markdown]
# ### Categorias que existen

# %%
df['Genres'].unique()
# Out:
# array(['Casual,Indie,Sports', 'Action,Indie',
#        'Action,Adventure,Indie,Strategy', ...,
#        'Action,Massively Multiplayer,RPG,Strategy,Free to Play',
#        'Action,Indie,RPG,Simulation,Sports,Strategy',
#        'Action,Casual,Indie,Simulation,Free to Play'], dtype=object)

# %%
df['Genres'].nunique()
# Out:
# 2471
